# %% [raw]
# ---
# description: Explore data outside the context of a model
# output-file: explore.html
# title: Explore Data
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(show_correlation)
# Out:
# ---
#
# [source](https://github.com/gsganden/model_inspector/tree/main/blob/main/model_inspector/explore.py#L16){target="_blank" style="float:right; font-size:smaller"}
#
# ### show_correlation
#
# >      show_correlation (df:pandas.core.frame.DataFrame, method='pearson',
# >                        cmap='PuBu', low:float=0, high:float=0,
# >                        axis:Axis|None=0, subset:Subset|None=None,
# >                        text_color_threshold:float=0.408, vmin:float|None=None,
# >                        vmax:float|None=None, gmap:Sequence|None=None)
#
# Show correlation heatmap
#
# If output is not rendering properly when you reopen a notebook, make
# sure the notebook is trusted.
#
# Parameters:
#
# - `df`: DataFrame
# - `method`: Method of correlation to pass to `df.corr()`
#
#     Remaining parameters are passed to `pandas.io.formats.style.background_gradient`.

# %%
import sklearn.datasets

# %%
X_diabetes, y_diabetes = sklearn.datasets.load_diabetes(return_X_y=True, as_frame=True)

# %%
show_correlation(pd.concat((X_diabetes, y_diabetes), axis="columns"))
# Out:
# <style type="text/css">
# #T_78121_row0_col0, #T_78121_row1_col1, #T_78121_row2_col2, #T_78121_row3_col3, #T_78121_row4_col4, #T_78121_row5_col5, #T_78121_row6_col6, #T_78121_row7_col7, #T_78121_row8_col8, #T_78121_row9_col9, #T_78121_row10_col10 {
#   background-color: #ff0000;
#   color: #f1f1f1;
# }
# #T_78121_row0_col1, #T_78121_row1_col0, #T_78121_row5_col10, #T_78121_row10_col5 {
#   background-color: #ffd2d2;
#   color: #000000;
# }
# #T_78121_row0_col2, #T_78121_row2_col0, #T_78121_row3_col5, #T_78121_row5_col3 {
#   background-color: #ffd0d0;
#   color: #000000;
# }
# #T_78121_row0_col3, #T_78121_row1_col7, #T_78121_row3_col0, #T_78121_row7_col1 {
#   background-color: #ffaaaa;
#   color: #000000;
# }
# #T_78121_row0_col4, #T_78121_row2_col5, #T_78121_row4_col0, #T_78121_row5_col2 {
#   background-color: #ffbcbc;
#   color: #000000;
# }
# #T_78121_row0_col5, #T_78121_row5_col0 {
#   background-color: #ffc6c6;
#   color: #000000;
# }
# #T_78121_row0_col6, #T_78121_row6_col0 {
#   background-color: #ececff;
#   color: #000000;
# }
# #T_78121_row0_col7, #T_78121_row1_col9, #T_78121_row7_col0, #T_78121_row9_col1 {
#   background-color: #ffcaca;
#   color: #000000;
# }
# #T_78121_row0_col8, #T_78121_row8_col0 {
#   background-color: #ffbaba;
#   color: #000000;
# }
# #T_78121_row0_col9, #T_78121_row9_col0 {
#   background-color: #ffb2b2;
#   color: #000000;
# }
# #T_78121_row0_col10, #T_78121_row10_col0 {
#   background-color: #ffcece;
#   color: #000000;
# }
# #T_78121_row1_col2, #T_78121_row2_col1 {
#   background-color: #ffe8e8;
#   color: #000000;
# }
# #T_78121_row1_col3, #T_78121_row3_col1 {
#   background-color: #ffc2c2;
#   color: #000000;
# }
# #T_78121_row1_col4, #T_78121_row4_col1 {
#   background-color: #fff6f6;
#   color: #000000;
# }
# #T_78121_row1_col5, #T_78121_row5_col1 {
#   background-color: #ffdada;
#   color: #000000;
# }
# #T_78121_row1_col6, #T_78121_row6_col1 {
#   background-color: #9e9eff;
#   color: #f1f1f1;
# }
# #T_78121_row1_col8, #T_78121_row8_col1 {
#   background-color: #ffd8d8;
#   color: #000000;
# }
# #T_78121_row1_col10, #T_78121_row10_col1 {
#   background-color: #fff4f4;
#   color: #000000;
# }
# #T_78121_row2_col3, #T_78121_row3_col2, #T_78121_row3_col8, #T_78121_row8_col3 {
#   background-color: #ff9a9a;
#   color: #000000;
# }
# #T_78121_row2_col4, #T_78121_row3_col4, #T_78121_row4_col2, #T_78121_row4_col3 {
#   background-color: #ffc0c0;
#   color: #000000;
# }
# #T_78121_row2_col6, #T_78121_row6_col2 {
#   background-color: #a2a2ff;
#   color: #f1f1f1;
# }
# #T_78121_row2_col7, #T_78121_row7_col2 {
#   background-color: #ff9696;
#   color: #000000;
# }
# #T_78121_row2_col8, #T_78121_row8_col2 {
#   background-color: #ff8c8c;
#   color: #000000;
# }
# #T_78121_row2_col9, #T_78121_row3_col9, #T_78121_row9_col2, #T_78121_row9_col3 {
#   background-color: #ff9c9c;
#   color: #000000;
# }
# #T_78121_row2_col10, #T_78121_row10_col2 {
#   background-color: #ff6868;
#   color: #f1f1f1;
# }
# #T_78121_row3_col6, #T_78121_row6_col3 {
#   background-color: #d2d2ff;
#   color: #000000;
# }
# #T_78121_row3_col7, #T_78121_row7_col3 {
#   background-color: #ffbebe;
#   color: #000000;
# }
# #T_78121_row3_col10, #T_78121_row10_col3 {
#   background-color: #ff8e8e;
#   color: #000000;
# }
# #T_78121_row4_col5, #T_78121_row5_col4 {
#   background-color: #ff1a1a;
#   color: #f1f1f1;
# }
# #T_78121_row4_col6, #T_78121_row6_col4 {
#   background-color: #fff2f2;
#   color: #000000;
# }
# #T_78121_row4_col7, #T_78121_row7_col4 {
#   background-color: #ff7474;
#   color: #f1f1f1;
# }
# #T_78121_row4_col8, #T_78121_row8_col4 {
#   background-color: #ff7c7c;
#   color: #f1f1f1;
# }
# #T_78121_row4_col9, #T_78121_row9_col4 {
#   background-color: #ffacac;
#   color: #000000;
# }
# #T_78121_row4_col10, #T_78121_row10_col4 {
#   background-color: #ffc8c8;
#   color: #000000;
# }
# #T_78121_row5_col6, #T_78121_row6_col5 {
#   background-color: #ccccff;
#   color: #000000;
# }
# #T_78121_row5_col7, #T_78121_row7_col5 {
#   background-color: #ff5656;
#   color: #f1f1f1;
# }
# #T_78121_row5_col8, #T_78121_row8_col5 {
#   background-color: #ffaeae;
#   color: #000000;
# }
# #T_78121_row5_col9, #T_78121_row9_col5 {
#   background-color: #ffb4b4;
#   color: #000000;
# }
# #T_78121_row6_col7, #T_78121_row7_col6 {
#   background-color: #4242ff;
#   color: #f1f1f1;
# }
# #T_78121_row6_col8, #T_78121_row8_col6 {
#   background-color: #9898ff;
#   color: #f1f1f1;
# }
# #T_78121_row6_col9, #T_78121_row9_col6 {
#   background-color: #b8b8ff;
#   color: #000000;
# }
# #T_78121_row6_col10, #T_78121_row10_col6 {
#   background-color: #9a9aff;
#   color: #f1f1f1;
# }
# #T_78121_row7_col8, #T_78121_row8_col7 {
#   background-color: #ff6060;
#   color: #f1f1f1;
# }
# #T_78121_row7_col9, #T_78121_row9_col7 {
#   background-color: #ff9494;
#   color: #000000;
# }
# #T_78121_row7_col10, #T_78121_row10_col7 {
#   background-color: #ff9090;
#   color: #000000;
# }
# #T_78121_row8_col9, #T_78121_row9_col8 {
#   background-color: #ff8888;
#   color: #f1f1f1;
# }
# #T_78121_row8_col10, #T_78121_row10_col8 {
#   background-color: #ff6e6e;
#   color: #f1f1f1;
# }
# #T_78121_row9_col10, #T_78121_row10_col9 {
#   background-color: #ff9e9e;
#   color: #000000;
# }
# </style>
# <table id="T_78121">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_78121_level0_col0" class="col_heading level0 col0" >age</th>
#       <th id="T_78121_level0_col1" class="col_heading level0 col1" >sex</th>
#       <th id="T_78121_level0_col2" class="col_heading level0 col2" >bmi</th>
#       <th id="T_78121_level0_col3" class="col_heading level0 col3" >bp</th>
#       <th id="T_78121_level0_col4" class="col_heading level0 col4" >s1</th>
#       <th id="T_78121_level0_col5" class="col_heading level0 col5" >s2</th>
#       <th id="T_78121_level0_col6" class="col_heading level0 col6" >s3</th>
#       <th id="T_78121_level0_col7" class="col_heading level0 col7" >s4</th>
#       <th id="T_78121_level0_col8" class="col_heading level0 col8" >s5</th>
#       <th id="T_78121_level0_col9" class="col_heading level0 col9" >s6</th>
#       <th id="T_78121_level0_col10" class="col_heading level0 col10" >target</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_78121_level0_row0" class="row_heading level0 row0" >age</th>
#       <td id="T_78121_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_78121_row0_col1" class="data row0 col1" >0.17</td>
#       <td id="T_78121_row0_col2" class="data row0 col2" >0.19</td>
#       <td id="T_78121_row0_col3" class="data row0 col3" >0.34</td>
#       <td id="T_78121_row0_col4" class="data row0 col4" >0.26</td>
#       <td id="T_78121_row0_col5" class="data row0 col5" >0.22</td>
#       <td id="T_78121_row0_col6" class="data row0 col6" >-0.08</td>
#       <td id="T_78121_row0_col7" class="data row0 col7" >0.20</td>
#       <td id="T_78121_row0_col8" class="data row0 col8" >0.27</td>
#       <td id="T_78121_row0_col9" class="data row0 col9" >0.30</td>
#       <td id="T_78121_row0_col10" class="data row0 col10" >0.19</td>
#     </tr>
#     <tr>
#       <th id="T_78121_level0_row1" class="row_heading level0 row1" >sex</th>
#       <td id="T_78121_row1_col0" class="data row1 col0" >0.17</td>
#       <td id="T_78121_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_78121_row1_col2" class="data row1 col2" >0.09</td>
#       <td id="T_78121_row1_col3" class="data row1 col3" >0.24</td>
#       <td id="T_78121_row1_col4" class="data row1 col4" >0.04</td>
#       <td id="T_78121_row1_col5" class="data row1 col5" >0.14</td>
#       <td id="T_78121_row1_col6" class="data row1 col6" >-0.38</td>
#       <td id="T_78121_row1_col7" class="data row1 col7" >0.33</td>
#       <td id="T_78121_row1_col8" class="data row1 col8" >0.15</td>
#       <td id="T_78121_row1_col9" class="data row1 col9" >0.21</td>
#       <td id="T_78121_row1_col10" class="data row1 col10" >0.04</td>
#     </tr>
#     <tr>
#       <th id="T_78121_level0_row2" class="row_heading level0 row2" >bmi</th>
#       <td id="T_78121_row2_col0" class="data row2 col0" >0.19</td>
#       <td id="T_78121_row2_col1" class="data row2 col1" >0.09</td>
#       <td id="T_78121_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_78121_row2_col3" class="data row2 col3" >0.40</td>
#       <td id="T_78121_row2_col4" class="data row2 col4" >0.25</td>
#       <td id="T_78121_row2_col5" class="data row2 col5" >0.26</td>

# %%
iris = sklearn.datasets.load_iris()
X_iris, y_iris = iris["data"], iris["target"]
y_iris = pd.Series(y_iris, name="iris type").map(
    {num: name for num, name in zip([0, 1, 2], iris["target_names"])}
)
X_iris = pd.DataFrame(X_iris, columns=iris["feature_names"])

# %%
show_correlation(
    pd.concat((X_iris, pd.Series(y_iris == "setosa", name="setosa"))), method="spearman"
)
# Out:
# /var/folders/wv/pmfhhk1d4h1fkd_z5l83m0dw0000gq/T/ipykernel_96080/529445965.py:15: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   return df.corr(method=method).style.background_gradient(**kwargs).format("{0:,.2f}")
# <style type="text/css">
# #T_4ae20_row0_col0, #T_4ae20_row1_col1, #T_4ae20_row2_col2, #T_4ae20_row3_col3 {
#   background-color: #ff0000;
#   color: #f1f1f1;
# }
# #T_4ae20_row0_col1, #T_4ae20_row1_col0 {
#   background-color: #d4d4ff;
#   color: #000000;
# }
# #T_4ae20_row0_col2, #T_4ae20_row2_col0 {
#   background-color: #ff1e1e;
#   color: #f1f1f1;
# }
# #T_4ae20_row0_col3, #T_4ae20_row3_col0 {
#   background-color: #ff2a2a;
#   color: #f1f1f1;
# }
# #T_4ae20_row1_col2, #T_4ae20_row2_col1 {
#   background-color: #b0b0ff;
#   color: #000000;
# }
# #T_4ae20_row1_col3, #T_4ae20_row3_col1 {
#   background-color: #b6b6ff;
#   color: #000000;
# }
# #T_4ae20_row2_col3, #T_4ae20_row3_col2 {
#   background-color: #ff0e0e;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_4ae20">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4ae20_level0_col0" class="col_heading level0 col0" >sepal length (cm)</th>
#       <th id="T_4ae20_level0_col1" class="col_heading level0 col1" >sepal width (cm)</th>
#       <th id="T_4ae20_level0_col2" class="col_heading level0 col2" >petal length (cm)</th>
#       <th id="T_4ae20_level0_col3" class="col_heading level0 col3" >petal width (cm)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4ae20_level0_row0" class="row_heading level0 row0" >sepal length (cm)</th>
#       <td id="T_4ae20_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_4ae20_row0_col1" class="data row0 col1" >-0.17</td>
#       <td id="T_4ae20_row0_col2" class="data row0 col2" >0.88</td>
#       <td id="T_4ae20_row0_col3" class="data row0 col3" >0.83</td>
#     </tr>
#     <tr>
#       <th id="T_4ae20_level0_row1" class="row_heading level0 row1" >sepal width (cm)</th>
#       <td id="T_4ae20_row1_col0" class="data row1 col0" >-0.17</td>
#       <td id="T_4ae20_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_4ae20_row1_col2" class="data row1 col2" >-0.31</td>
#       <td id="T_4ae20_row1_col3" class="data row1 col3" >-0.29</td>
#     </tr>
#     <tr>
#       <th id="T_4ae20_level0_row2" class="row_heading level0 row2" >petal length (cm)</th>
#       <td id="T_4ae20_row2_col0" class="data row2 col0" >0.88</td>
#       <td id="T_4ae20_row2_col1" class="data row2 col1" >-0.31</td>
#       <td id="T_4ae20_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_4ae20_row2_col3" class="data row2 col3" >0.94</td>
#     </tr>
#     <tr>
#       <th id="T_4ae20_level0_row3" class="row_heading level0 row3" >petal width (cm)</th>
#       <td id="T_4ae20_row3_col0" class="data row3 col0" >0.83</td>
#       <td id="T_4ae20_row3_col1" class="data row3 col1" >-0.29</td>
#       <td id="T_4ae20_row3_col2" class="data row3 col2" >0.94</td>
#       <td id="T_4ae20_row3_col3" class="data row3 col3" >1.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
#| echo: false
#| output: asis
show_doc(plot_column_clusters)
# Out:
# ---
#
# [source](https://github.com/gsganden/model_inspector/tree/main/blob/main/model_inspector/explore.py#L32){target="_blank" style="float:right; font-size:smaller"}
#
# ### plot_column_clusters
#
# >      plot_column_clusters (df, corr_method:str='spearman',
# >                            ax:matplotlib.axes._axes.Axes=None, p=30,
# >                            truncate_mode=None, color_threshold=None,
# >                            get_leaves=True, orientation='top', labels=None,
# >                            count_sort=False, distance_sort=False,
# >                            show_leaf_counts=True, no_plot=False,
# >                            no_labels=False, leaf_font_size=None,
# >                            leaf_rotation=None, leaf_label_func=None,
# >                            show_contracted=False, link_color_func=None,
# >                            above_threshold_color='C0')
#
# Plot a dendrogram based on column correlations
#
# If output is not rendering properly when you reopen a notebook, make
# sure the notebook is trusted.
#
# Adapted from
# [https://github.com/fastai/book_nbs/blob/master/utils.py#L58-L64](https://github.com/fastai/book_nbs/blob/master/utils.py#L58-L64)
#
# Parameters:
#
# - `df`: DataFrame
# - `corr_method`: Method of correlation to pass to `df.corr()`
# - `ax`: Matplotlib `Axes` object. Plot will be added to this object
# if provided; otherwise a new `Axes` object will be generated.
#
#     Remaining parameters are passed to `scipy.cluster.hierarchy.dendrogram`.

# %%
ax = plot_column_clusters(X_iris)
