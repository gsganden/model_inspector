# %% [raw]
# ---
# description: Inspector functionality specific to estimators that inherit from `BaseSearchCV`
# output-file: searchcv_estimator.html
# title: SearchCV
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
import sklearn.datasets
from model_inspector import get_inspector
from sklearn.model_selection import GridSearchCV, KFold
from sklearn.tree import DecisionTreeRegressor

X, y = sklearn.datasets.load_breast_cancer(return_X_y=True, as_frame=True)

# %%
grid = GridSearchCV(
    estimator=DecisionTreeRegressor(),
    param_grid={
        "min_samples_leaf": (1, 2, 5, 10, 20, 50),
        "max_features": (0.3, 0.5, 1.0),
        "splitter": ("best", "random"),
    },
    n_jobs=-1,
    return_train_score=True,
    cv=KFold(5, shuffle=True),
).fit(X, y)

# %%
inspector = get_inspector(grid, X, y)

# %%
#| echo: false
#| output: asis
show_doc(_SearchCVInspector.plot_scores_vs_hparam)
# Out:
# ---
#
# [source](https://github.com/gsganden/model_inspector/tree/main/blob/main/model_inspector/inspect/searchcv_estimator.py#LNone){target="_blank" style="float:right; font-size:smaller"}
#
# ### _SearchCVInspector.plot_scores_vs_hparam
#
# >      _SearchCVInspector.plot_scores_vs_hparam (hparam:Optional[str]=None,
# >                                                score_cols:Union[str,Sequence[s
# >                                                tr],NoneType]=None, ax=None)
#
# Plot model scores against values of one hyperparameter
#
# Parameters:
#
# - `hparam`: Name of the hyperparameter to plot against. Must be
# provided if there are multiple hyperparameters. Any other
# hyperparameters will be fixed at the value they have in
# `self.model.best_params_`.
# - `score_cols`: Name of score columns to plot. By default will
# be the mean test and (if present) train score for the primary
# scoring metric.
# - `ax`: Matplotlib `Axes` object. Plot will be added to this object
# if provided; otherwise a new `Axes` object will be generated.

# %%
ax = inspector.plot_scores_vs_hparam("min_samples_leaf")
ax = inspector.plot_scores_vs_hparam("max_features")
ax = inspector.plot_scores_vs_hparam("splitter")

# %%
#| echo: false
#| output: asis
show_doc(_SearchCVInspector.show_score_vs_hparam_pair)
# Out:
# ---
#
# [source](https://github.com/gsganden/model_inspector/tree/main/blob/main/model_inspector/inspect/searchcv_estimator.py#LNone){target="_blank" style="float:right; font-size:smaller"}
#
# ### _SearchCVInspector.show_score_vs_hparam_pair
#
# >      _SearchCVInspector.show_score_vs_hparam_pair (hparams=None,
# >                                                    score_col=None,
# >                                                    cmap='PuBu', low:float=0,
# >                                                    high:float=0,
# >                                                    axis:Axis|None=0,
# >                                                    subset:Subset|None=None, te
# >                                                    xt_color_threshold:float=0.
# >                                                    408, vmin:float|None=None,
# >                                                    vmax:float|None=None,
# >                                                    gmap:Sequence|None=None)
#
# Show model scores against a pair of hyperparameters.
#
# Background gradient uses `axis=None` by default, to facilitate
# identifying the best score across all combinations of
# hyperparameter values.
#
# Parameters:
#
# - `hparams`: Name of the hyperparameters to plot against.
# The first two hyperparameters in `self.model.param_grid` will be
# used by default. Any other hyperparameters will be fixed at the
# value they have in `self.model.best_params_`.
# - `score_col`: Name of score column to plot. By default will
# be the mean test score for the primary scoring metric.
#
# Remaining parameters are passed to `pandas.io.formats.style.background_gradient`.

# %%
inspector.show_score_vs_hparam_pair(["min_samples_leaf", "max_features"])
# Out:
# <style type="text/css">
# #T_b136a_row0_col0 {
#   background-color: #b1c2de;
#   color: #000000;
# }
# #T_b136a_row0_col1 {
#   background-color: #96b6d7;
#   color: #000000;
# }
# #T_b136a_row0_col2 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_b136a_row1_col0 {
#   background-color: #75a9cf;
#   color: #f1f1f1;
# }
# #T_b136a_row1_col1 {
#   background-color: #71a8ce;
#   color: #f1f1f1;
# }
# #T_b136a_row1_col2 {
#   background-color: #c0c9e2;
#   color: #000000;
# }
# #T_b136a_row2_col0 {
#   background-color: #3790c0;
#   color: #f1f1f1;
# }
# #T_b136a_row2_col1 {
#   background-color: #0d75b3;
#   color: #f1f1f1;
# }
# #T_b136a_row2_col2, #T_b136a_row3_col2 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_b136a_row3_col0 {
#   background-color: #2786bb;
#   color: #f1f1f1;
# }
# #T_b136a_row3_col1 {
#   background-color: #046097;
#   color: #f1f1f1;
# }
# #T_b136a_row4_col0 {
#   background-color: #1e80b8;
#   color: #f1f1f1;
# }
# #T_b136a_row4_col1 {
#   background-color: #197db7;
#   color: #f1f1f1;
# }
# #T_b136a_row4_col2 {
#   background-color: #045483;
#   color: #f1f1f1;
# }
# #T_b136a_row5_col0 {
#   background-color: #9fbad9;
#   color: #000000;
# }
# #T_b136a_row5_col1 {
#   background-color: #acc0dd;
#   color: #000000;
# }
# #T_b136a_row5_col2 {
#   background-color: #88b1d4;
#   color: #000000;
# }
# </style>
# <table id="T_b136a">
#   <thead>
#     <tr>
#       <th class="index_name level0" >param_max_features</th>
#       <th id="T_b136a_level0_col0" class="col_heading level0 col0" >0.300000</th>
#       <th id="T_b136a_level0_col1" class="col_heading level0 col1" >0.500000</th>
#       <th id="T_b136a_level0_col2" class="col_heading level0 col2" >1.000000</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >param_min_samples_leaf</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b136a_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_b136a_row0_col0" class="data row0 col0" >0.692566</td>
#       <td id="T_b136a_row0_col1" class="data row0 col1" >0.703389</td>
#       <td id="T_b136a_row0_col2" class="data row0 col2" >0.643111</td>
#     </tr>
#     <tr>
#       <th id="T_b136a_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_b136a_row1_col0" class="data row1 col0" >0.715289</td>
#       <td id="T_b136a_row1_col1" class="data row1 col1" >0.716811</td>
#       <td id="T_b136a_row1_col2" class="data row1 col2" >0.686538</td>
#     </tr>
#     <tr>
#       <th id="T_b136a_level0_row2" class="row_heading level0 row2" >5</th>
#       <td id="T_b136a_row2_col0" class="data row2 col0" >0.733478</td>
#       <td id="T_b136a_row2_col1" class="data row2 col1" >0.749070</td>
#       <td id="T_b136a_row2_col2" class="data row2 col2" >0.788384</td>
#     </tr>
#     <tr>
#       <th id="T_b136a_level0_row3" class="row_heading level0 row3" >10</th>
#       <td id="T_b136a_row3_col0" class="data row3 col0" >0.739222</td>
#       <td id="T_b136a_row3_col1" class="data row3 col1" >0.764752</td>
#       <td id="T_b136a_row3_col2" class="data row3 col2" >0.788066</td>
#     </tr>
#     <tr>
#       <th id="T_b136a_level0_row4" class="row_heading level0 row4" >20</th>
#       <td id="T_b136a_row4_col0" class="data row4 col0" >0.742443</td>
#       <td id="T_b136a_row4_col1" class="data row4 col1" >0.744197</td>
#       <td id="T_b136a_row4_col2" class="data row4 col2" >0.773343</td>
#     </tr>
#     <tr>
#       <th id="T_b136a_level0_row5" class="row_heading level0 row5" >50</th>
#       <td id="T_b136a_row5_col0" class="data row5 col0" >0.699997</td>
#       <td id="T_b136a_row5_col1" class="data row5 col1" >0.694785</td>
#       <td id="T_b136a_row5_col2" class="data row5 col2" >0.708409</td>
#     </tr>
#   </tbody>
# </table>
