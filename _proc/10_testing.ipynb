# %% [raw]
# ---
# description: Testing
# output-file: testing.html
# title: Testing
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
from nbdev.showdoc import *

# %%
#| echo: false
#| output: asis
show_doc(_Test.foo)
# Out:
# ---
#
# [source](https://github.com/gsganden/model_inspector/tree/main/blob/main/model_inspector/inspect/testing.py#L23){target="_blank" style="float:right; font-size:smaller"}
#
# ### _Test.foo
#
# >      _Test.foo (x:Any)
#
# Foo.
#
# Parameters:
#
# - `x`: An x
