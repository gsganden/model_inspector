# %% [raw]
# ---
# description: Utilities for working with Python classes
# output-file: class_utils.html
# title: Class Utils
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(delegates)
# Out:
# ---
#
# [source](https://github.com/gsganden/model_inspector/tree/main/blob/main/model_inspector/class_utils.py#L10){target="_blank" style="float:right; font-size:smaller"}
#
# ### delegates
#
# >      delegates (to=None, keep=False)
#
# Decorator: replace `**kwargs` in signature with params from `to`
#
# Adapted from
# [https://fastcore.fast.ai/meta.html#delegates](https://fastcore.fast.ai/meta.html#delegates)
