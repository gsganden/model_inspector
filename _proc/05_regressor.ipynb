# %% [raw]
# ---
# description: Inspector functionality for any regression model
# output-file: regressor.html
# title: Regressor
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
import sklearn.datasets
from model_inspector import get_inspector
from model_inspector.inspect.regressor import _RegInspector
from sklearn.linear_model import LinearRegression

X, y = sklearn.datasets.load_diabetes(return_X_y=True, as_frame=True)
inspector = get_inspector(LinearRegression().fit(X, y), X, y)
assert isinstance(inspector, _RegInspector)

# %%
inspector.methods
# Out:
# ['_generate_model_html',
#  '_plot_waterfall',
#  'permutation_importance',
#  'plot_coefs_vs_hparam',
#  'plot_dependence',
#  'plot_feature_clusters',
#  'plot_permutation_importance',
#  'plot_pred_vs_act',
#  'plot_residuals',
#  'plot_waterfall',
#  'show_correlation',
#  'show_model']

# %%
axes = inspector.plot_residuals()

# %%
ax = inspector.plot_pred_vs_act()
